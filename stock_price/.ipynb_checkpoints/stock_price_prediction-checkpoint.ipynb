# %% [markdown]
# # Forecasting Apple Stock Price

# %% [markdown]
# In this project, I will build a Long short-term memory (LSTM) model to predict the future stock prices of Apple Company (AAPL), based on its stock prices of the past 10 years. LSTM is an artificial recurrent neural network that has feedback connections.

# %% [markdown]
# The data for this project can be downloaded from [here](https://finance.yahoo.com/quote/AAPL/history?p=AAPL&.tsrc=fin-srch). I downloaded the data from 09/01/2010 to 09/30/2020. There are 2,538 tuples in the dataset, each representing a day's stock market attributes for Apple

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse

import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import Callback, EarlyStopping
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_table("AAPL.csv", delimiter=",")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2010-09-01  8.838214  8.980714  8.795714  8.940357   7.725714  697037600
# 1  2010-09-02  8.973572  9.006071  8.877500  9.006071   7.782502  415427600
# 2  2010-09-03  9.110357  9.242143  9.089286  9.241786   7.986192  520788800
# 3  2010-09-07  9.165714  9.268929  9.151786  9.207500   7.956563  342557600
# 4  2010-09-08  9.277857  9.442500  9.253572  9.390000   8.114268  526551200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2538 entries, 0 to 2537
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2538 non-null   object
#  1   Open       2538 non-null   float64
#  2   High       2538 non-null   float64
#  3   Low        2538 non-null   float64
#  4   Close      2538 non-null   float64
#  5   Adj Close  2538 non-null   float64
#  6   Volume     2538 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 138.9+ KB

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# * Covert data type of ``Date`` to ``pd.date_time``
# * Sort data by ``Date`` (the raw data should be sorted already, but just in case)
# * Extract features

# %%
df.set_index(pd.to_datetime(df['Date']), inplace=True)
df.sort_index(ascending=True, inplace=True)

# %%
features = ["Open", "High", "Low", "Close", "Volume"]
df = df[features]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# It's always a good idea to visualize your data first

# %%
df.drop(["Volume"], axis=1).plot(figsize=(12,6))
plt.ylabel("stock price")
# Out:
# Text(0, 0.5, 'stock price')

# %%
df["Volume"].plot(figsize=(12,6))
plt.ylabel("traded volume")
# Out:
# Text(0, 0.5, 'traded volume')

# %% [markdown]
# You can see there are quite some surges in the number of transactions on and before 2014. Let's take a look at the most extreme one.

# %%
df.iloc[np.argmax(df["Volume"]),:]
# Out:
# Open      1.176857e+01
# High      1.231286e+01
# Low       1.164286e+01
# Close     1.216607e+01
# Volume    1.880998e+09
# Name: 2011-01-18 00:00:00, dtype: float64

# %% [markdown]
# Via a Google search, we found out that this sucess is led by the fact that Apple company sold 7.3 million iPads in the quarter. Based on this [CNN blog](https://money.cnn.com/2011/01/18/technology/apple_earnings/index.htm), this result was "surpassing the expectations of nearly every Wall Street analyst."

# %% [markdown]
# # Data Preparation

# %% [markdown]
# There are a few steps need to be done to build a LSTM model

# %% [markdown]
# ### Spliting and normalizing data

# %%
train, test = train_test_split(df, train_size=0.8, test_size=0.2, shuffle=False)
sc = MinMaxScaler(feature_range=(0,1))
train = sc.fit_transform(train.values)
test = sc.transform(test.values)
print("We have", len(train), "train data samples and", len(test), "test data samples.")
print("The test data later will be splitted into an evaluation set and a test set")
# Out:
# We have 2030 train data samples and 508 test data samples.
# The test data later will be splitted into an evaluation set and a test set

# %% [markdown]
# ### Constructing time-series data

# %%
def make_timeseries_data(data, look_back, y_col=3):
    X, Y = [], []
    for i in range(len(data)-look_back):
        x = data[i:(i+look_back)]
        y = data[i+look_back, y_col]
        X.append(x)
        Y.append(y)
    return np.array(X), np.array(Y)

# %% [markdown]
# ### Triming data

# %%
def trim_for_batch(data, batch_size):
    num_rows_to_drop = data.shape[0] % batch_size
    if num_rows_to_drop>0:
        data = data[:-num_rows_to_drop]
    return data

# %% [markdown]
# We will forecast a day's close stock price for AAPL using data from the previous 30 days. For example, use data from 1st April 2020 to 30 April 2020 to predict the close price on 1st May 2020. Therefore, each training sequence has a length of 30

# %%
LOOK_BACK = 30
BATCH_SIZE = 50

x_train, y_train = make_timeseries_data(train, LOOK_BACK)
x_train = trim_for_batch(x_train, BATCH_SIZE)
y_train = trim_for_batch(y_train, BATCH_SIZE)

x_temp, y_temp = make_timeseries_data(test, LOOK_BACK)
x_val, x_test = np.split(trim_for_batch(x_temp, BATCH_SIZE), 2)
y_val, y_test = np.split(trim_for_batch(y_temp, BATCH_SIZE), 2)

# %% [markdown]
# # Model Building

# %% [markdown]
# We only have 2,538 entries in the data, so we will build a shallow network that has one LSTM layer and one Dense layer. Building a deep network is prone to overfitting, and given the data size, it's likely to be starved.

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# # Model Training

# %%
# customize callback function
class Evaluate(Callback):
    def __init__(self, x_val, y_val):
        self.best = 1e9
        self.x_val = x_val
        self.y_val = y_val
        
    def evaluate(self):
        val_pred = model.predict(self.x_val, verbose=1)
        val_pred = val_pred.flatten()
        score = mse(self.y_val, val_pred)
        return score

    def on_epoch_end(self, epoch, logs=None):
        score = self.evaluate()
        if score < self.best:
            self.best = score
            model.save_weights("best_model.weights")
        print("current mse: %.4f, best mse: %.4f\n" % (score, self.best))

# %%
evaluator = Evaluate(x_val, y_val)

history = model.fit(x_train, y_train, 
                    epochs=40, 
                    batch_size=BATCH_SIZE, 
                    shuffle=False,
                    validation_data=(x_val, y_val),  
                    callbacks=[evaluator]
                )
# Out:
# Train on 2000 samples, validate on 225 samples
# Epoch 1/40
# 2000/2000 [==============================] - 2s 1ms/step - loss: 0.0034 - val_loss: 0.0014
# 225/225 [==============================] - 0s 911us/step
# current mse: 0.0014, best mse: 0.0014
#
# Epoch 2/40
# 2000/2000 [==============================] - 2s 781us/step - loss: 0.0029 - val_loss: 0.0020
# 225/225 [==============================] - 0s 415us/step
# current mse: 0.0020, best mse: 0.0014
#
# Epoch 3/40
# 2000/2000 [==============================] - 2s 768us/step - loss: 0.0015 - val_loss: 0.0012
# 225/225 [==============================] - 0s 423us/step
# current mse: 0.0012, best mse: 0.0012
#
# Epoch 4/40
# 2000/2000 [==============================] - 2s 782us/step - loss: 0.0013 - val_loss: 0.0016
# 225/225 [==============================] - 0s 544us/step
# current mse: 0.0016, best mse: 0.0012
#
# Epoch 5/40
# 2000/2000 [==============================] - 2s 758us/step - loss: 0.0011 - val_loss: 7.0412e-04
# 225/225 [==============================] - 0s 372us/step
# current mse: 0.0007, best mse: 0.0007
#
# Epoch 6/40
# 2000/2000 [==============================] - 2s 797us/step - loss: 0.0011 - val_loss: 5.8114e-04
# 225/225 [==============================] - 0s 412us/step
# current mse: 0.0006, best mse: 0.0006
#
# Epoch 7/40
# 2000/2000 [==============================] - 2s 778us/step - loss: 9.9600e-04 - val_loss: 6.3474e-04
# 225/225 [==============================] - 0s 396us/step
# current mse: 0.0006, best mse: 0.0006
#
# Epoch 8/40
# 2000/2000 [==============================] - 2s 792us/step - loss: 9.5569e-04 - val_loss: 5.5285e-04
# 225/225 [==============================] - 0s 510us/step
# current mse: 0.0006, best mse: 0.0006
#
# Epoch 9/40
# 2000/2000 [==============================] - 2s 877us/step - loss: 6.6288e-04 - val_loss: 5.6761e-04
# 225/225 [==============================] - 0s 378us/step
# current mse: 0.0006, best mse: 0.0006
#
# Epoch 10/40
# 2000/2000 [==============================] - 2s 807us/step - loss: 7.4659e-04 - val_loss: 5.6590e-04
# 225/225 [==============================] - 0s 590us/step
# current mse: 0.0006, best mse: 0.0006
#
# Epoch 11/40
# 2000/2000 [==============================] - 2s 770us/step - loss: 6.9014e-04 - val_loss: 5.7316e-04
# 225/225 [==============================] - 0s 394us/step
# current mse: 0.0006, best mse: 0.0006
#
# Epoch 12/40
# 2000/2000 [==============================] - 2s 770us/step - loss: 6.5368e-04 - val_loss: 9.9830e-04
# 225/225 [==============================] - 0s 446us/step
# current mse: 0.0010, best mse: 0.0006
#
# Epoch 13/40
# 2000/2000 [==============================] - 2s 1ms/step - loss: 9.2047e-04 - val_loss: 5.9131e-04
# 225/225 [==============================] - 0s 403us/step
# current mse: 0.0006, best mse: 0.0006
#
# Epoch 14/40
# 2000/2000 [==============================] - 2s 814us/step - loss: 6.8616e-04 - val_loss: 6.3102e-04
# 225/225 [==============================] - 0s 418us/step
# current mse: 0.0006, best mse: 0.0006
#
# Epoch 15/40
# 2000/2000 [==============================] - 2s 887us/step - loss: 6.2325e-04 - val_loss: 5.1874e-04
# 225/225 [==============================] - 0s 387us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 16/40
# 2000/2000 [==============================] - 3s 1ms/step - loss: 5.8916e-04 - val_loss: 5.1517e-04
# 225/225 [==============================] - 0s 425us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 17/40
# 2000/2000 [==============================] - 2s 922us/step - loss: 5.5870e-04 - val_loss: 7.0788e-04
# 225/225 [==============================] - 0s 529us/step
# current mse: 0.0007, best mse: 0.0005
#
# Epoch 18/40
# 2000/2000 [==============================] - 2s 956us/step - loss: 5.6367e-04 - val_loss: 5.5191e-04
# 225/225 [==============================] - 0s 516us/step
# current mse: 0.0006, best mse: 0.0005
#
# Epoch 19/40
# 2000/2000 [==============================] - 2s 1ms/step - loss: 6.4873e-04 - val_loss: 6.7618e-04
# 225/225 [==============================] - 0s 416us/step
# current mse: 0.0007, best mse: 0.0005
#
# Epoch 20/40
# 2000/2000 [==============================] - 2s 977us/step - loss: 9.2350e-04 - val_loss: 6.7130e-04
# 225/225 [==============================] - 0s 534us/step
# current mse: 0.0007, best mse: 0.0005
#
# Epoch 21/40
# 2000/2000 [==============================] - 2s 933us/step - loss: 6.4950e-04 - val_loss: 5.4205e-04
# 225/225 [==============================] - 0s 475us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 22/40
# 2000/2000 [==============================] - 2s 901us/step - loss: 7.0714e-04 - val_loss: 5.0063e-04
# 225/225 [==============================] - 0s 439us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 23/40
# 2000/2000 [==============================] - 2s 999us/step - loss: 6.1396e-04 - val_loss: 5.4703e-04
# 225/225 [==============================] - 0s 436us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 24/40
# 2000/2000 [==============================] - 2s 837us/step - loss: 5.5204e-04 - val_loss: 5.1080e-04
# 225/225 [==============================] - 0s 423us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 25/40
# 2000/2000 [==============================] - 2s 938us/step - loss: 6.3048e-04 - val_loss: 5.9697e-04
# 225/225 [==============================] - 0s 372us/step
# current mse: 0.0006, best mse: 0.0005
#
# Epoch 26/40
# 2000/2000 [==============================] - 2s 867us/step - loss: 5.9384e-04 - val_loss: 6.4200e-04
# 225/225 [==============================] - 0s 463us/step
# current mse: 0.0006, best mse: 0.0005
#
# Epoch 27/40
# 2000/2000 [==============================] - 2s 893us/step - loss: 5.2612e-04 - val_loss: 5.0195e-04
# 225/225 [==============================] - 0s 369us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 28/40
# 2000/2000 [==============================] - 2s 848us/step - loss: 6.1790e-04 - val_loss: 6.7181e-04
# 225/225 [==============================] - 0s 436us/step
# current mse: 0.0007, best mse: 0.0005
#
# Epoch 29/40
# 2000/2000 [==============================] - 2s 861us/step - loss: 4.6982e-04 - val_loss: 4.7937e-04
# 225/225 [==============================] - 0s 502us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 30/40
# 2000/2000 [==============================] - 2s 825us/step - loss: 5.3455e-04 - val_loss: 5.1668e-04
# 225/225 [==============================] - 0s 444us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 31/40
# 2000/2000 [==============================] - 2s 862us/step - loss: 4.5873e-04 - val_loss: 4.7811e-04
# 225/225 [==============================] - 0s 449us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 32/40
# 2000/2000 [==============================] - 2s 926us/step - loss: 4.9149e-04 - val_loss: 5.6805e-04
# 225/225 [==============================] - 0s 424us/step
# current mse: 0.0006, best mse: 0.0005
#
# Epoch 33/40
# 2000/2000 [==============================] - 2s 837us/step - loss: 4.9433e-04 - val_loss: 4.8178e-04
# 225/225 [==============================] - 0s 379us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 34/40
# 2000/2000 [==============================] - 2s 883us/step - loss: 5.4517e-04 - val_loss: 6.3995e-04
# 225/225 [==============================] - 0s 417us/step
# current mse: 0.0006, best mse: 0.0005
#
# Epoch 35/40
# 2000/2000 [==============================] - 2s 848us/step - loss: 7.3195e-04 - val_loss: 8.0014e-04
# 225/225 [==============================] - 0s 437us/step
# current mse: 0.0008, best mse: 0.0005
#
# Epoch 36/40
# 2000/2000 [==============================] - 2s 922us/step - loss: 6.3411e-04 - val_loss: 5.3383e-04
# 225/225 [==============================] - 0s 392us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 37/40
# 2000/2000 [==============================] - 2s 930us/step - loss: 5.8854e-04 - val_loss: 5.4003e-04
# 225/225 [==============================] - 0s 381us/step
# current mse: 0.0005, best mse: 0.0005
#
# Epoch 38/40
# 2000/2000 [==============================] - 2s 843us/step - loss: 5.6402e-04 - val_loss: 6.4190e-04
# 225/225 [==============================] - 0s 398us/step
# current mse: 0.0006, best mse: 0.0005
#
# Epoch 39/40
# 2000/2000 [==============================] - 2s 814us/step - loss: 4.7654e-04 - val_loss: 5.5427e-04
# 225/225 [==============================] - 0s 392us/step
# current mse: 0.0006, best mse: 0.0005
#
# Epoch 40/40
# 2000/2000 [==============================] - 2s 774us/step - loss: 4.7468e-04 - val_loss: 4.5797e-04
# 225/225 [==============================] - 0s 382us/step
# current mse: 0.0005, best mse: 0.0005

# %% [markdown]
# Plot train loss and test loss to see if our model is overfitting

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %% [markdown]
# # Forecasting

# %%
model.load_weights("best_model.weights")

y_pred = model.predict(trim_for_batch(x_test, BATCH_SIZE), batch_size=BATCH_SIZE)

# %% [markdown]
# # Model Performance Evaluation

# %%
y_pred = y_pred.flatten()
y_test = trim_for_batch(y_test, BATCH_SIZE)
y_pred_org = (y_pred * sc.data_range_[3]) + sc.data_min_[3]
y_test_org = (y_test * sc.data_range_[3]) + sc.data_min_[3]
error = mse(y_test_org, y_pred_org)
print("The MSE is", error)
# Out:
# The MSE is 3.9677353307061254

# %%
plt.figure(figsize=(12,6))
plt.plot(y_pred_org)
plt.plot(y_test_org)
plt.title('Prediction vs Real Stock Price')
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')
plt.show()
